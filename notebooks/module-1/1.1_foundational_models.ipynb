# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
import os

if not os.getenv("GOOGLE_API_KEY"):
    raise ValueError("GOOGLE_API_KEY is missing. Add it to your .env file or environment variables.")

# %%
import sys
print(sys.executable)
# Out:
# y:\PROJECTS\RAG-PRACTICE\langchain_practice\lca-lc-foundations\.venv\Scripts\python.exe

# %% [markdown]
# ## Initialising and invoking a model

# %%
from langchain.chat_models import init_chat_model

model = init_chat_model(
    model="gemini-2.5-flash",
    model_provider="google_genai",
)

# %%
response = model.invoke("What's the capital of the Moon?")

response
# Out:
# AIMessage(content="The Moon does not have a capital.\n\nIt's not a country or a political entity, and it doesn't have a permanent human settlement or government. While there have been many proposals for lunar bases and even future colonies, none have been established to the point of needing or designating a capital city.", additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019de8ae-1eb0-7a22-8ff2-1ae2ad9c2a26-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 10, 'output_tokens': 643, 'total_tokens': 653, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 581}})

# %%
print(response.content)
# Out:
# The Moon does not have a capital.
#
# It's not a country or a political entity, and it doesn't have a permanent human settlement or government. While there have been many proposals for lunar bases and even future colonies, none have been established to the point of needing or designating a capital city.

# %%
from pprint import pprint

pprint(response.response_metadata)
# Out:
# {'finish_reason': 'STOP',
#  'model_name': 'gemini-2.5-flash',
#  'model_provider': 'google_genai',
#  'safety_ratings': []}

# %% [markdown]
# ## Customising your Model

# %%
model = init_chat_model(
    model="gemini-2.5-flash",
    model_provider="google_genai",
    # Kwargs passed to the model:
    temperature=1.0,
)

response = model.invoke("What's the capital of the Moon?")
print(response.content)
# Out:
# The Moon does not have a capital.
#
# It's a celestial body, not a country or a political entity with a government or permanent settlements that would designate a capital city.

# %% [markdown]
# ## Model Providers

# %% [markdown]
# https://docs.langchain.com/oss/python/integrations/chat

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

model = ChatGoogleGenerativeAI(model="gemini-2.5-flash-lite")

response = model.invoke("What's the capital of the Moon?")
print(response.content)
# Out:
# The Moon doesn't have a capital city because it's not a country or a populated territory with a government. It's a natural celestial body.

# %% [markdown]
# ## Initialising and invoking an agent

# %%
from langchain.agents import create_agent

agent = create_agent(model=model)

# %%
agent = create_agent("google_genai:gemini-2.5-flash")

# %%
from langchain.messages import HumanMessage

response = agent.invoke(
    {"messages": [HumanMessage(content="What's the capital of the Moon?")]}
)

# %%
from pprint import pprint

pprint(response)
# Out:
# {'messages': [HumanMessage(content="What's the capital of the Moon?", additional_kwargs={}, response_metadata={}, id='bb2f169d-301d-4ba2-a652-b7dec53247ed'),
#               AIMessage(content='The Moon doesn\'t have a capital city!\n\nThis is because it\'s a natural celestial body without any native inhabitants, governments, or political structures. Capital cities are concepts related to human societies and countries.\n\nWhile there are many fictional depictions of Moon bases and cities in science fiction, none of these are real, and even within fiction, there isn\'t one universally agreed-upon "capital of the Moon" that has been established.', additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019de8b2-1269-73b3-af6f-dcb2166abef6-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 10, 'output_tokens': 813, 'total_tokens': 823, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 723}})]}

# %%
print(response['messages'][-1].content)
# Out:
# The Moon doesn't have a capital city!
#
# This is because it's a natural celestial body without any native inhabitants, governments, or political structures. Capital cities are concepts related to human societies and countries.
#
# While there are many fictional depictions of Moon bases and cities in science fiction, none of these are real, and even within fiction, there isn't one universally agreed-upon "capital of the Moon" that has been established.

# %%
from langchain.messages import AIMessage

response = agent.invoke(
    {"messages": [HumanMessage(content="What's the capital of the Moon?"),
    AIMessage(content="The capital of the Moon is Luna City."),
    HumanMessage(content="Interesting, tell me more about Luna City, but Moon is a celestial object, not a country.")]}
)

pprint(response)
print(f"Response: {response['messages'][-1].content}")
# Out:
# {'messages': [HumanMessage(content="What's the capital of the Moon?", additional_kwargs={}, response_metadata={}, id='712af3ce-dbab-4ec7-b9b4-f0b51cc37153'),
#               AIMessage(content='The capital of the Moon is Luna City.', additional_kwargs={}, response_metadata={}, id='711bef18-a984-4d26-bf92-6130291cb5d5', tool_calls=[], invalid_tool_calls=[]),
#               HumanMessage(content='Interesting, tell me more about Luna City', additional_kwargs={}, response_metadata={}, id='e5028264-855b-42bd-b2f2-e8d12b310b3a'),
#               AIMessage(content='Ah, Luna City! It\'s a fantastic concept that often appears in science fiction and future projections of lunar colonization. Since it\'s a fictional construct, its details can vary, but here\'s a composite picture based on common portrayals:\n\n**What is Luna City?**\n\nLuna City is envisioned as the primary human settlement on the Moon, serving as its administrative, economic, and scientific capital. It represents humanity\'s most ambitious step beyond Earth, a testament to our ingenuity and drive to explore and colonize space.\n\n**Key Characteristics and Features:**\n\n1.  **Location:** While its exact location varies in different stories, it\'s often envisioned in a strategically important area:\n    *   **Polar Craters (e.g., Shackleton):** For access to valuable water ice deposits, crucial for life support, rocket fuel, and industrial processes.\n    *   **Major Craters (e.g., Tycho, Copernicus):** Providing natural shielding from radiation and micrometeoroids, and often offering dramatic views of Earth.\n    *   **Near the Earth-facing side:** To maintain easier communication and transport links with Earth.\n\n2.  **Architecture and Design:**\n    *   **Pressurized Domes:** Vast, transparent or translucent domes covering large areas, allowing for Earth-like atmospheres, parks, and recreational spaces, while providing views of the lunar landscape.\n    *   **Underground Tunnels and Caverns:** Extensive networks beneath the surface, offering superior protection from solar and cosmic radiation, micrometeoroids, and extreme temperature fluctuations. These often house residential areas, industrial zones, power generators, and transportation hubs.\n    *   **Modular Construction:** Buildings and habitats are typically designed to be modular and expandable, allowing for organic growth as the city\'s population and needs increase.\n    *   **Lunar Regolith Utilization:** Utilizing local materials (lunar soil/regolith) for construction, perhaps through 3D printing, or as shielding.\n\n3.  **Purpose and Role (as a "Capital"):**\n    *   **Administrative Hub:** The central point for governance and coordination of all lunar activities – research, resource extraction, space traffic control, and establishing lunar law.\n    *   **Research & Development:** A leading center for astrobiology, astrophysics, materials science, and developing new technologies for space exploration and off-world living.\n    *   **Resource Processing:** A major site for processing valuable lunar resources like helium-3 (a potential clean fusion fuel), water ice, and rare earth elements.\n    *   **Spaceport & Tourism:** A primary gateway for arrivals and departures from Earth, and a burgeoning tourist destination offering unique low-gravity experiences and unparalleled views of Earth.\n\n4.  **Life in Luna City:**\n    *   **Low Gravity Recreation:** Sports and activities specifically designed for 1/6th gravity, offering unique physical experiences.\n    *   **Controlled Environments:** Indoor parks, hydroponic farms providing fresh food, and advanced life support systems ensuring breathable air and recycled water.\n    *   **International Community:** A diverse population of scientists, engineers, miners, entrepreneurs, and artists from all over Earth, creating a vibrant, multicultural society.\n    *   **Technologically Advanced:** Life would be highly dependent on advanced technology for survival, comfort, and exploration.\n\n**In essence, Luna City is the dream of a permanent human foothold on another celestial body – a beacon of future exploration, innovation, and a potential "second home" for humanity.**', additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019de8b3-3505-70d1-9e52-1146574b4bcd-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 29, 'output_tokens': 1945, 'total_toke ...
# Response: Ah, Luna City! It's a fantastic concept that often appears in science fiction and future projections of lunar colonization. Since it's a fictional construct, its details can vary, but here's a composite picture based on common portrayals:
#
# **What is Luna City?**
#
# Luna City is envisioned as the primary human settlement on the Moon, serving as its administrative, economic, and scientific capital. It represents humanity's most ambitious step beyond Earth, a testament to our ingenuity and drive to explore and colonize space.
#
# **Key Characteristics and Features:**
#
# 1.  **Location:** While its exact location varies in different stories, it's often envisioned in a strategically important area:
#     *   **Polar Craters (e.g., Shackleton):** For access to valuable water ice deposits, crucial for life support, rocket fuel, and industrial processes.
#     *   **Major Craters (e.g., Tycho, Copernicus):** Providing natural shielding from radiation and micrometeoroids, and often offering dramatic views of Earth.
#     *   **Near the Earth-facing side:** To maintain easier communication and transport links with Earth.
#
# 2.  **Architecture and Design:**
#     *   **Pressurized Domes:** Vast, transparent or translucent domes covering large areas, allowing for Earth-like atmospheres, parks, and recreational spaces, while providing views of the lunar landscape.
#     *   **Underground Tunnels and Caverns:** Extensive networks beneath the surface, offering superior protection from solar and cosmic radiation, micrometeoroids, and extreme temperature fluctuations. These often house residential areas, industrial zones, power generators, and transportation hubs.
#     *   **Modular Construction:** Buildings and habitats are typically designed to be modular and expandable, allowing for organic growth as the city's population and needs increase.
#     *   **Lunar Regolith Utilization:** Utilizing local materials (lunar soil/regolith) for construction, perhaps through 3D printing, or as shielding.
#
# 3.  **Purpose and Role (as a "Capital"):**
#     *   **Administrative Hub:** The central point for governance and coordination of all lunar activities – research, resource extraction, space traffic control, and establishing lunar law.
#     *   **Research & Development:** A leading center for astrobiology, astrophysics, materials science, and developing new technologies for space exploration and off-world living.
#     *   **Resource Processing:** A major site for processing valuable lunar resources like helium-3 (a potential clean fusion fuel), water ice, and rare earth elements.
#     *   **Spaceport & Tourism:** A primary gateway for arrivals and departures from Earth, and a burgeoning tourist destination offering unique low-gravity experiences and unparalleled views of Earth.
#
# 4.  **Life in Luna City:**
#     *   **Low Gravity Recreation:** Sports and activities specifically designed for 1/6th gravity, offering unique physical experiences.
#     *   **Controlled Environments:** Indoor parks, hydroponic farms providing fresh food, and advanced life support systems ensuring breathable air and recycled water.
#     *   **International Community:** A diverse population of scientists, engineers, miners, entrepreneurs, and artists from all over Earth, creating a vibrant, multicultural society.
#     *   **Technologically Advanced:** Life would be highly dependent on advanced technology for survival, comfort, and exploration.
#
# **In essence, Luna City is the dream of a permanent human foothold on another celestial body – a beacon of future exploration, innovation, and a potential "second home" for humanity.**

# %% [markdown]
# ## Streaming Output

# %%
for token, metadata in agent.stream(
    {"messages": [HumanMessage(content="Tell me all about Luna City, the capital of the Moon")]},
    stream_mode="messages"
):

    # token is a message chunk with token content
    # metadata contains which node produced the token
    
    if token.content:  # Check if there's actual content
        print(token.content, end="", flush=True)  # Print token
