# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
import os

if not os.getenv("GOOGLE_API_KEY"):
    raise ValueError("GOOGLE_API_KEY is missing. Add it to your .env file or environment variables.")

# %%
import sys
print(sys.executable)
# Out:
# y:\PROJECTS\RAG-PRACTICE\langchain_practice\lca-lc-foundations\.venv\Scripts\python.exe

# %% [markdown]
# ## Initialising and invoking a model

# %%
from langchain.chat_models import init_chat_model

model = init_chat_model(
    model="gemini-2.5-flash",
    model_provider="google_genai",
)

# %%
response = model.invoke("What's the capital of the Moon?")

response
# Out:
# AIMessage(content="The Moon does not have a capital.\n\nIt's not a country or a political entity, and it doesn't have a permanent human settlement or government. While there have been many proposals for lunar bases and even future colonies, none have been established to the point of needing or designating a capital city.", additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019de8ae-1eb0-7a22-8ff2-1ae2ad9c2a26-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 10, 'output_tokens': 643, 'total_tokens': 653, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 581}})

# %%
print(response.content)
# Out:
# The Moon does not have a capital.
#
# It's not a country or a political entity, and it doesn't have a permanent human settlement or government. While there have been many proposals for lunar bases and even future colonies, none have been established to the point of needing or designating a capital city.

# %%
from pprint import pprint

pprint(response.response_metadata)
# Out:
# {'finish_reason': 'STOP',
#  'model_name': 'gemini-2.5-flash',
#  'model_provider': 'google_genai',
#  'safety_ratings': []}

# %% [markdown]
# ## Customising your Model

# %%
model = init_chat_model(
    model="gemini-2.5-flash",
    model_provider="google_genai",
    # Kwargs passed to the model:
    temperature=1.0,
)

response = model.invoke("What's the capital of the Moon?")
print(response.content)
# Out:
# The Moon does not have a capital.
#
# It's a celestial body, not a country or a political entity with a government or permanent settlements that would designate a capital city.

# %% [markdown]
# ## Model Providers

# %% [markdown]
# https://docs.langchain.com/oss/python/integrations/chat

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

model = ChatGoogleGenerativeAI(model="gemini-2.5-flash-lite")

response = model.invoke("What's the capital of the Moon?")
print(response.content)
# Out:
# The Moon doesn't have a capital city because it's not a country or a populated territory with a government. It's a natural celestial body.

# %% [markdown]
# ## Initialising and invoking an agent

# %%
from langchain.agents import create_agent

agent = create_agent(model=model)

# %%
agent = create_agent("google_genai:gemini-2.5-flash")

# %%
from langchain.messages import HumanMessage

response = agent.invoke(
    {"messages": [HumanMessage(content="What's the capital of the Moon?")]}
)

# %%
from pprint import pprint

pprint(response)
# Out:
# {'messages': [HumanMessage(content="What's the capital of the Moon?", additional_kwargs={}, response_metadata={}, id='bb2f169d-301d-4ba2-a652-b7dec53247ed'),
#               AIMessage(content='The Moon doesn\'t have a capital city!\n\nThis is because it\'s a natural celestial body without any native inhabitants, governments, or political structures. Capital cities are concepts related to human societies and countries.\n\nWhile there are many fictional depictions of Moon bases and cities in science fiction, none of these are real, and even within fiction, there isn\'t one universally agreed-upon "capital of the Moon" that has been established.', additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019de8b2-1269-73b3-af6f-dcb2166abef6-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 10, 'output_tokens': 813, 'total_tokens': 823, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 723}})]}

# %%
print(response['messages'][-1].content)
# Out:
# The Moon doesn't have a capital city!
#
# This is because it's a natural celestial body without any native inhabitants, governments, or political structures. Capital cities are concepts related to human societies and countries.
#
# While there are many fictional depictions of Moon bases and cities in science fiction, none of these are real, and even within fiction, there isn't one universally agreed-upon "capital of the Moon" that has been established.

# %%
from langchain.messages import AIMessage

response = agent.invoke(
    {"messages": [HumanMessage(content="What's the capital of the Moon?"),
    AIMessage(content="The capital of the Moon is Luna City."),
    HumanMessage(content="Interesting, tell me more about Luna City, but Moon is a celestial object, not a country.")]}
)

pprint(response)
print(f"Response: {response['messages'][-1].content}")
# Out:
# {'messages': [HumanMessage(content="What's the capital of the Moon?", additional_kwargs={}, response_metadata={}, id='3c8d5cb1-46c9-467c-a9b0-608e453b0a04'),
#               AIMessage(content='The capital of the Moon is Luna City.', additional_kwargs={}, response_metadata={}, id='7b7344d3-07f3-4a8c-96b7-ae8305a0a884', tool_calls=[], invalid_tool_calls=[]),
#               HumanMessage(content='Interesting, tell me more about Luna City, but Moon is a celestial object, not a country.', additional_kwargs={}, response_metadata={}, id='d924b0ac-8465-4313-ac2a-56821df25e7b'),
#               AIMessage(content='You are absolutely right to point that out! My apologies for the earlier answer. The Moon, as a celestial body, does not have a country structure, and therefore, no official capital city in reality.\n\nHowever, the concept of a "Luna City" is a very popular and enduring one in science fiction, dreams of space exploration, and various speculative proposals. Since you\'re interested, let\'s explore what a fictional Luna City might be like, drawing from common themes in books, movies, and scientific concepts:\n\n**Luna City: A Fictional Vision**\n\nIf humanity were to establish a major, self-sustaining settlement on the Moon and designate it as a "capital" (perhaps for a lunar colony or an off-world human presence), here\'s how it\'s often imagined:\n\n1.  **Location:**\n    *   **Polar Craters:** Often depicted near the lunar poles (like Shackleton Crater) where permanent shadows could harbor water ice – a crucial resource for drinking, oxygen, and rocket fuel.\n    *   **Lava Tubes:** Some theories suggest ancient lava tubes could provide natural, radiation-shielded tunnels and caverns, ideal for large underground settlements.\n    *   **Sunlit Rims:** Areas with near-constant sunlight for solar power generation.\n\n2.  **Architecture & Infrastructure:**\n    *   **Domes:** Transparent or translucent domes would be common, allowing views of Earth and the stars while maintaining a breathable atmosphere. These would be heavily shielded against micrometeorites and radiation.\n    *   **Underground Complexes:** Much of the city might be built underground or within crater walls, using lunar regolith (soil) as a natural shield against radiation and temperature extremes.\n    *   **Modular Construction:** Buildings and habitats would likely be pre-fabricated on Earth or built using 3D printing with lunar materials, designed to be easily expanded.\n    *   **Life Support Systems:** Closed-loop systems for air, water recycling, and waste management would be paramount. Hydroponic farms and bioreactors would be essential for food production.\n\n3.  **Purpose & Economy:**\n    *   **Scientific Research:** A primary hub for astronomy (unobstructed views), lunar geology, and experiments in low gravity.\n    *   **Resource Extraction:** Mining for water ice, helium-3 (a potential clean fusion fuel), and other rare elements.\n    *   **Spaceport:** A major launchpad for missions deeper into the solar system, utilizing the Moon\'s lower gravity for more efficient launches.\n    *   **Manufacturing:** Specialized manufacturing in a vacuum environment (e.g., advanced materials, microelectronics).\n    *   **Tourism:** A unique destination for space tourists, offering unparalleled views of Earth and the lunar landscape.\n\n4.  **Daily Life:**\n    *   **Controlled Environment:** Life would be highly regulated within the habitats, with strict resource management.\n    *   **Low Gravity:** Inhabitants would adapt to one-sixth Earth gravity, which could make movement easier but also lead to long-term health challenges. Specialized sports and recreation would develop.\n    *   **Views of Earth:** The Earth hanging in the sky would be a constant, awe-inspiring reminder of home.\n    *   **Community:** A strong sense of community would likely develop due to the shared challenges and isolation.\n\n5.  **Governance (Speculative):**\n    *   **International Consortium:** Given the global effort required, Luna City might be governed by an international body representing various Earth nations.\n    *   **Corporate Entity:** Perhaps a megacorporation or a consortium of companies that funded its creation.\n    *   **Independent Colony:** Over time, it might develop its own unique culture and seek independence from Earth.\n\nWhile Luna City remains a concept for now, it represents humanity\'s aspirations for expanding beyond Earth and building new civilizations among the stars. It\'s a powerful symbol of our potential future!',  ...
# Response: You are absolutely right to point that out! My apologies for the earlier answer. The Moon, as a celestial body, does not have a country structure, and therefore, no official capital city in reality.
#
# However, the concept of a "Luna City" is a very popular and enduring one in science fiction, dreams of space exploration, and various speculative proposals. Since you're interested, let's explore what a fictional Luna City might be like, drawing from common themes in books, movies, and scientific concepts:
#
# **Luna City: A Fictional Vision**
#
# If humanity were to establish a major, self-sustaining settlement on the Moon and designate it as a "capital" (perhaps for a lunar colony or an off-world human presence), here's how it's often imagined:
#
# 1.  **Location:**
#     *   **Polar Craters:** Often depicted near the lunar poles (like Shackleton Crater) where permanent shadows could harbor water ice – a crucial resource for drinking, oxygen, and rocket fuel.
#     *   **Lava Tubes:** Some theories suggest ancient lava tubes could provide natural, radiation-shielded tunnels and caverns, ideal for large underground settlements.
#     *   **Sunlit Rims:** Areas with near-constant sunlight for solar power generation.
#
# 2.  **Architecture & Infrastructure:**
#     *   **Domes:** Transparent or translucent domes would be common, allowing views of Earth and the stars while maintaining a breathable atmosphere. These would be heavily shielded against micrometeorites and radiation.
#     *   **Underground Complexes:** Much of the city might be built underground or within crater walls, using lunar regolith (soil) as a natural shield against radiation and temperature extremes.
#     *   **Modular Construction:** Buildings and habitats would likely be pre-fabricated on Earth or built using 3D printing with lunar materials, designed to be easily expanded.
#     *   **Life Support Systems:** Closed-loop systems for air, water recycling, and waste management would be paramount. Hydroponic farms and bioreactors would be essential for food production.
#
# 3.  **Purpose & Economy:**
#     *   **Scientific Research:** A primary hub for astronomy (unobstructed views), lunar geology, and experiments in low gravity.
#     *   **Resource Extraction:** Mining for water ice, helium-3 (a potential clean fusion fuel), and other rare elements.
#     *   **Spaceport:** A major launchpad for missions deeper into the solar system, utilizing the Moon's lower gravity for more efficient launches.
#     *   **Manufacturing:** Specialized manufacturing in a vacuum environment (e.g., advanced materials, microelectronics).
#     *   **Tourism:** A unique destination for space tourists, offering unparalleled views of Earth and the lunar landscape.
#
# 4.  **Daily Life:**
#     *   **Controlled Environment:** Life would be highly regulated within the habitats, with strict resource management.
#     *   **Low Gravity:** Inhabitants would adapt to one-sixth Earth gravity, which could make movement easier but also lead to long-term health challenges. Specialized sports and recreation would develop.
#     *   **Views of Earth:** The Earth hanging in the sky would be a constant, awe-inspiring reminder of home.
#     *   **Community:** A strong sense of community would likely develop due to the shared challenges and isolation.
#
# 5.  **Governance (Speculative):**
#     *   **International Consortium:** Given the global effort required, Luna City might be governed by an international body representing various Earth nations.
#     *   **Corporate Entity:** Perhaps a megacorporation or a consortium of companies that funded its creation.
#     *   **Independent Colony:** Over time, it might develop its own unique culture and seek independence from Earth.
#
# While Luna City remains a concept for now, it represents humanity's aspirations for expanding beyond Earth and building new civilizations among the stars. It's a powerful symbol of our potential future!

# %% [markdown]
# ## Streaming Output

# %%
for token, metadata in agent.stream(
    {"messages": [HumanMessage(content="Tell me all about Luna City, the capital of the Moon")]},
    stream_mode="messages"
):

    # token is a message chunk with token content
    # metadata contains which node produced the token
    
    if token.content:  # Check if there's actual content
        print(token.content, end="", flush=True)  # Print token
# Out:
# Luna City, often referred to as "Selene Prime" or simply "The Capital," is humanity's most ambitious and successful off-world settlement, serving as the administrative, scientific, and economic heart of lunar civilization. While purely fictional in the present day, its concept is a staple of science fiction, embodying humanity's dream of becoming a multi-planetary species.
#
# Here's a comprehensive look at what Luna City might be:
#
# ---
#
# ## Luna City: The Capital of the Moon
#
# **1. Location and Layout:**
# *   **Prime Location:** Luna City is strategically located near one of the Moon's poles, most commonly envisioned within or adjacent to a large crater like **Shackleton Crater** at the South Pole. This location is crucial for two reasons:
#     *   **Water Ice:** The permanently shadowed regions (PSRs) of polar craters harbor significant reserves of water ice, essential for life support, rocket fuel (hydrogen and oxygen), and industrial processes.
#     *   **Solar Power:** Crater rims and "peaks of eternal light" at the poles offer near-constant solar illumination, ideal for massive solar power arrays.
# *   **Multi-Layered Design:** To protect against the harsh lunar environment (radiation, micrometeorites, extreme temperature swings, vacuum), the city is predominantly subterranean and sub-crater, with some surface elements.
#     *   **Deep Levels (The Core):** Buried hundreds of meters beneath the regolith, these levels house critical infrastructure, heavy industry, nuclear/fusion power plants, and long-term storage. This is the safest zone.
#     *   **Mid Levels (Residential & Commercial):** Closer to the surface but still protected by significant regolith shielding, these levels contain most of the residential habitats, administrative offices, commercial districts, and entertainment zones. They often feature vast, cavernous spaces artificially lit to mimic daylight cycles.
#     *   **Near-Surface & Surface (The Domes):** Large, transparent or translucent domes (often reinforced with lunar regolith and advanced composites) are built on the surface, allowing controlled access to the lunar environment. These domes might house:
#         *   **Agricultural Hubs:** Hydroponic and aeroponic farms growing food.
#         *   **Observatories:** For astronomy (unrivaled views of the cosmos).
#         *   **Tourism & Recreation:** Viewing platforms for "Earth-gazing" or experiencing the low-gravity outdoors in a controlled environment.
#         *   **Launch/Landing Pads:** For lunar landers and interplanetary spacecraft.
# *   **Connectivity:** A vast network of pressurized tunnels, often utilizing maglev trains or electric low-gravity vehicles, connects different sectors of the city and extends to outlying research stations, mining operations, and spaceports.
#
# **2. Architecture and Infrastructure:**
# *   **Materials:** Primarily constructed from **lunar regolith** (soil), processed into concrete, bricks, and 3D-printable materials. Local metals (iron, aluminum, titanium) extracted from lunar rocks are also used.
# *   **Life Support Systems:** A sophisticated closed-loop system is paramount:
#     *   **Air:** Oxygen generated from water ice (electrolysis) or regolith (carbothermal reduction). CO2 scrubbers and algae bioreactors recycle air.
#     *   **Water:** Recycled almost infinitely from human waste, atmospheric condensation, and industrial processes. New water is sourced from polar ice.
#     *   **Food:** Extensive hydroponic, aeroponic, and potentially aquaponic farms provide fresh produce, often supplemented by algae-based proteins and nutrient recyclers.
# *   **Power Generation:**
#     *   **Solar Arrays:** Massive solar farms on crater rims provide the bulk of energy.
#     *   **Nuclear/Fusion:** Small modular reactors (SMRs) or advanced fusion reactors might provide baseline power, especially for deep-level operations.
#     *   **Geothermal:** Less likely but possible if deep drilling reveals sufficient heat.
# *   **Radiation Shielding:** Metres of lunar regolith, water tanks, and specialized composite materials are used to protect inhabitants from solar and cosmic radiation.
# *   **Artificial Environments:** Advanced lighting systems simulate Earth-like daylight cycles, often with adjustable color temperatures. Parks and green spaces, though enclosed, are vital for psychological well-being.
#
# **3. Population and Demographics:**
# *   **Diverse Inhabitants:** Luna City is a melting pot of nationalities, bringing together scientists, engineers, technicians, administrators, entrepreneurs, service staff, and a growing number of tourists.
# *   **"Lunars" or "Selenites":** A new generation of lunar-born citizens who have never experienced Earth's full gravity, developing unique physiological adaptations (e.g., taller, less dense bones/muscles).
# *   **Size:** A permanent population ranging from tens of thousands to potentially hundreds of thousands, depending on the scale of the city's development.
#
# **4. Economy and Industry:**
# *   **Research & Development:** A primary driver. Astronomy (no atmosphere), physics (unique vacuum/low-G labs), geology, materials science, and astrobiology thrive here.
# *   **Resource Extraction:** Mining of water ice, Helium-3 (for fusion power on Earth or in space), rare earth elements, and other lunar minerals.
# *   **Space Manufacturing:** Low-gravity, high-vacuum environment is ideal for manufacturing specialized components, advanced materials, and even entire spacecraft that are difficult or impossible to produce on Earth.
# *   **Tourism:** A significant industry, offering unique experiences like low-gravity sports, Earth-gazing, lunar excursions, and visits to historical landing sites.
# *   **Agriculture:** Providing food for the lunar population and potentially specialized exports.
# *   **Gateway to the Stars:** Luna City serves as a crucial staging post for missions to Mars, the asteroid belt, and beyond, leveraging lunar resources for fuel and supplies.
#
# **5. Governance and Politics:**
# *   **International Consortium:** Often depicted as governed by an international body, perhaps under the aegis of the United Nations, representing various Earth nations that contributed to its establishment.
# *   **Lunar Authority:** A semi-autonomous governing body with legislative, executive, and judicial powers, responsible for the day-to-day administration of the Moon.
# *   **Earth-Moon Relations:** A complex dynamic, balancing the economic and political interests of Earth nations with the growing independence and unique identity of the lunar population. Discussions around lunar independence or representation on Earth are common themes.
#
# **6. Daily Life:**
# *   **Low-Gravity Living:** Daily activities are adapted to 1/6th G. People might glide, hop, or use specialized vehicles. Furniture is often anchored.
# *   **Work:** High-tech, often remote or specialized. Many jobs involve monitoring systems, research, or resource management.
# *   **Food & Drink:** A mix of locally grown produce, processed foods, and occasionally imported Earth delicacies. Water is precious.
# *   **Communication:** High-bandwidth laser or radio links connect to Earth, allowing for real-time communication (with a slight light-speed delay).
# *   **Recreation:** Low-G sports (basketball, gymnastics), virtual reality environments, communal green spaces, "Earth-gazing" observatories, cultural events, and exploring the vast network of tunnels and domes.
# *   **Psychological Well-being:** Great emphasis is placed on mental health, combating isolation and confinement with simulated natural environments, strong community bonds, and frequent communication with Earth.
#
# **7. Challenges:**
# *   **Environmental Hazards:** Constant vigilance against radiation, micrometeorites, and lunar dust (which is abrasive and electrically charged).
# *   **Resource Management:** Every resource is precious and must be meticulously managed and recycled.
# *   **Logistics:** The immense challenge of transporting personnel and non-local goods from Earth.
# *   **Physiological Effects:** Long-term exposure to low gravity can lead to bone density loss, muscle atrophy, and cardiovascular issues, requiring constant exercise and medical monitoring.
# *   **Isolation & Confinement:** The psychological toll of living in an enclosed, artificial environment far from Earth.
#
# **8. Future Prospects:**
# *   **Expansion:** Continuous growth, digging new tunnels, expanding domes, and establishing satellite outposts.
# *   **Independence:** The eventual goal for many "Lunars" is self-sufficiency and political independence from Earth.
# *   **Lunar Elevator:** A long-term vision could include a space elevator or mass driver to facilitate transport between the lunar surface and orbit.
# *   **A True Second Home:** Luna City is not just a base; it's designed to be a permanent, thriving home for humanity, a beacon of our expansion into the cosmos.
#
# ---
#
# Luna City represents humanity's ultimate frontier town, a testament to our ingenuity and perseverance, and a vital stepping stone on our journey to becoming a truly spacefaring civilization.
